# %% [markdown]
# <a href="https://colab.research.google.com/github/gitkimjob/kimjob_colab/blob/master/V-Express.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##音频驱动照片说话

# %%
# !git clone https://github.com/gitkimjob/E-Vxpress.git
# Out:
# Cloning into 'V-Express'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 221 (delta 14), reused 14 (delta 8), pack-reused 191
# Receiving objects: 100% (221/221), 142.82 MiB | 42.60 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# %cd /content/V-Express
# !pip install diffusers==0.24.0
# !pip install imageio-ffmpeg==0.4.9
# !pip install insightface==0.7.3
# !pip install omegaconf==2.2.3
# !pip install onnxruntime==1.16.3
# !pip install safetensors==0.4.2
# !pip install torch==2.0.1
# !pip install torchaudio==2.0.2
# !pip install torchvision==0.15.2
# !pip install transformers==4.30.2
# !pip install einops==0.4.1
# !pip install tqdm==4.66.1
# !pip install xformers==0.0.22
# !pip install av==11.0.0
# Out:
# /content/V-Express
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 43.9 MB/s eta 0:00:00
# ...
#   Created wheel for insightface: filename=insightface-0.7.3-cp310-cp310-linux_x86_64.whl size=1054140 sha256=934d2a17f59426b030142423491d49165881f83b8a53e6e6ecf8226afd657f8f
#   Stored in directory: /root/.cache/pip/wheels/e3/d0/80/e3773fb8b6d1cca87ea1d33d9b1f20a223a6493c896da249b5
# Successfully built insightface
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content/V-Express
# !git lfs install
# !git clone https://huggingface.co/tk93/V-Express
# !mv V-Express/model_ckpts model_ckpts
# Out:
# /content/V-Express
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'V-Express'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 50 (delta 5), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (50/50), 11.87 KiB | 1.08 MiB/s, done.
# Filtering content: 100% (12/12), 6.02 GiB | 42.46 MiB/s, done.

# %%
# !python inference.py \
    --reference_image_path "./test_samples/short_case/tys/ym.jpg" \
    --audio_path "./test_samples/short_case/tys/audio.mp3" \
    --output_path "./output/short_case/talk_tys_fix_face.mp4" \
    --retarget_strategy "fix_face" \
    --num_inference_steps 25
# Out:
# 2024-06-05 14:35:03.330572: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 14:35:03.330634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 14:35:03.337006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-05 14:35:05.109848: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
